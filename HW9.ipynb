# %%
import matplotlib.pyplot as plt
import numpy as np
n=1000

choice = np.random.randint(0,3,n)
prize = np.random.randint(0,3,n)
stay = prize[prize == choice]
switch = prize[choice != prize]

samples =  [1000]

def play_game(n):
    choice = np.random.randint(0,3,n)
    prize = np.random.randint(0,3,n)
    stay = prize[prize == choice]
    switch = prize[choice != prize]
    
    return [stay.size, switch.size]




fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,15))
        
ax1.bar(['stay','switch'], play_game(1000), color=['r','g'])
ax1.set_title('wins')
# Out:
# Text(0.5, 1.0, 'wins')

# %%
#2 half life 
from random import random
from numpy import arange
from pylab import plot,xlabel,ylabel,show


NPb= 0
NTl= 1000
tau = 3.3*60
tauT= 3.2*60
h=1.0
p= 1-2**(-h/tau)
pT= 1-2**(-h/tauT)
tmax = 1000

tpoint = np.arange(0.0,tmax,h)
Bipoints = []
Pbpoints=[]
Tlpoints=[]

for t in tpoints: 
    Bipoints.append(NBi) 
    Pbpoints.append(NPb) 
    Tlpoints.append(NTl)
    
 # Calculate the number of atoms that decay
    decay = 0
    for i in range(NBi): # determine number of atoms that decay
        if np.random.random() < 0.0209:
            decay += 1
        NBi -= decay # subtract number of decayed Parent atoms  # add number of decayed Daughter atoms 
        NTl += decay
    else:
        NBi -= decay
        NPb += decay
    


plot(tpoints,Bipoints, c='m') # plot Tl vs. time
plot(tpoints,Pbpoints, c='b') # plot Pb vs. time
xlabel("Time")
ylabel("Number of atoms")
show()

# %%
from random import random
from numpy import arange
from pylab import plot,xlabel,ylabel,show

# Constants
NTl = 10000             # Initial Number of thallium atoms
NPb = 0               # Number of lead atoms
tau = 3.053*60        # Half life of thallium in seconds
h = 1.0               # Size of time-step in seconds
p = 1 - 2**(-h/tau)   # Probability of decay in one step
tmax = 1000           # Total time

# Lists of plot points
tpoints = arange(0.0,tmax,h) # make time array
Tlpoints = [] # empty array to strore # of Tl atoms at each time step
Pbpoints = [] # empty array to strore # of Pb atoms at each time step

# Main loop
for t in tpoints:    # for time 0-1000 sec
    Tlpoints.append(NTl) # append starting # of Tl atoms
    Pbpoints.append(NPb) # append starting # of Pb atoms

    # Calculate the number of atoms that decay
    decay = 0
    for i in range(NTl): # determine number of atoms that decay
        if random() < p:
            decay += 1
    NTl -= decay # subtract number of decayed Parent atoms 
    NPb += decay # add number of decayed Daughter atoms 
    


# Make the graph
plot(tpoints,Tlpoints, c='m') # plot Tl vs. time
plot(tpoints,Pbpoints, c='b') # plot Pb vs. time
xlabel("Time")
ylabel("Number of atoms")
show()
